# %%
import psycopg2

# %%
conn = psycopg2.connect(
    dbname="bda_db",
    user="postgres",
    password="123456",
    host="localhost",
    port="5432"
)

print("Connected Successfully!")
# Out:
# Connected Successfully!

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT *from users_tbl")

# %%
print(cur.fetchall())
# Out:
# [(1, 'Alice Johnson', 'alice@example.com', 'hashed_password_1', datetime.datetime(2026, 6, 11, 0, 40, 28, 716672)), (2, 'Bob Smith', 'bob@example.com', 'hashed_password_2', datetime.datetime(2026, 6, 11, 0, 40, 28, 716672)), (3, 'Charlie Brown', 'charlie@example.com', 'hashed_password_3', datetime.datetime(2026, 6, 11, 0, 40, 28, 716672))]

# %%
print(cur.fetchone())
# Out:
# (1, 'Alice Johnson', 'alice@example.com', 'hashed_password_1', datetime.datetime(2026, 6, 11, 0, 40, 28, 716672))

# %%
print(cur.fetchone())
# Out:
# (2, 'Bob Smith', 'bob@example.com', 'hashed_password_2', datetime.datetime(2026, 6, 11, 0, 40, 28, 716672))

# %%
print(cur.fetchone())
# Out:
# (3, 'Charlie Brown', 'charlie@example.com', 'hashed_password_3', datetime.datetime(2026, 6, 11, 0, 40, 28, 716672))

# %%
print(cur.fetchone())
# Out:
# None

# %%
print(cur.fetchall())
# Out:
# []

# %%
cur.close()
conn.close()
